# %%
import pandas as pd
df=pd.read_csv("D:/download/labels.csv")
df
# Out:
#     ClassId                                               Name
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vechiles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# ...

# %%
import numpy as np
id=df['ClassId']
name=df.drop(['ClassId'],axis=1)
ID=id.values.tolist()
NAME=name.values.tolist()
dic = dict(zip(ID, NAME))


arr=np.array([1,12,3,15,56,7,98])
arr2=np.argmax(arr,axis=-1)
arr2
# Out:
# 6

# %%
def answer( classIndex):
    return dic[classIndex]

# %%
from keras.models import model_from_json
from operator import itemgetter
json_file=open("verzeoAItraffic.json","r")
loaded_model_json=json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights("verzeoAItrafficWeights.h5")
def preprocessing(image):
    image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    image = image/255
    return image
import cv2,numpy as np
capt=cv2.VideoCapture("00000_00000 - Copie.jpg")
capt.set(3,640)
capt.set(4,480)
capt.set(10,180)

capt.isOpened()
True
while True:
    message,image=capt.read()
    imagearr = np.asarray(image)
    imagearr=preprocessing(imagearr)
    imagearr=cv2.resize(imagearr,(32,32))
    imagearr=imagearr.reshape(1,32,32,1)
    prediction=loaded_model.predict(imagearr)
    classIndex = int(np.argmax(loaded_model.predict(imagearr), axis=-1))
    cv2.putText(image,"Class: ",(20,35),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),2)
    cv2.imshow("model prediction",image)
    probability=np.amax(prediction)
    if probability>0.75:
         cv2.putText(image,str(answer(classIndex)),(120,35),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),2)
        
    cv2.imshow("model prediction",image)
    cv2.waitKey(1)
    if cv2.waitKey(1) and 0xFF == ord('Q'):
        
  
       break
   
    cv2.destroyAllWindows
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6480ac23f5aa> in <module>
#      25     imagearr=imagearr.reshape(1,32,32,1)
#      26     prediction=loaded_model.predict(imagearr)
# ---> 27     classIndex = int(np.argmax(loaded_model.predict(imagearr), axis=-1))
#      28     cv2.putText(image,"Class: ",(20,35),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),2)
#      29     cv2.imshow("model prediction",image)
#
# E:\conda\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1718                         '. Consider setting it to AutoShardPolicy.DATA.')
#    1719
# -> 1720       data_handler = data_adapter.get_data_handler(
#    1721           x=x,
#    1722           batch_size=batch_size,
#
# ...
